# %% [markdown]
# ## Instructions
#
# You're going to run every cell in this notebook, that isn't labelled optional.
#
# The text which talks about the cell (if it has some) will be above it.
#
# If it contains **action** you need to change something in the cell, if it contains **context** then it's just explaining things to you.

# %% [markdown]
# **Action:** First we need to import the python library.
#
# You will need to install this first, it's not automatic. If you don't know how to install a python library I've got a beginners blog post on how to install a python library.
#
# Go follow that then come back :)

# %%
import daily_ga_data

# %% [markdown]
# **Action:**
#
# We need to set:
# - account_id
# - web_property_id
# - view_id
#
# These will select the GA account we're going to download from. We can most easily get these by opening up the [account explorer](https://ga-dev-tools.appspot.com/account-explorer/) and searching for the account we want to download from.

# %%
account_id = "1618063"
web_property_id = "UA-1618063-1"
view_id = "2901806"

# %% [markdown]
# **Action:**
#
# Then we need to some personalisation. The start and end date are self explanatory. They need to be in the format `YYYY-MM-DD`.
#
# - start_date
# - end_date

# %%
start_date = "2019-01-01"
end_date = "2019-01-02"

# %% [markdown]
# **Action:**
#
# Finally we need to set the location of the API key we've downloaded from Google.
#
# - auth_file
#
# If you're not sure how to get that API key, the instructions are in the blog post that accompanies this workbook.
#
# This needs to be the full path.
#
# **Windows:**
# If you're in Windows, the format of the path should look like this, with backslashes and an `r` at the start outside the quotes. Putting the `r` outside of the quotes allows us to use backslashes for the path.
#
# - `r"C:\Users\Dom_W\credentials\credentials.json"`
#
# (Obviously you'll need to set the path to wherever you downloaded your API key)
#
# **Mac/Linux:**
# If you're on Mac then the format of the path should look something like this.
#
# - `"/Users/Dom_W/credentials/credentials.json"`
#
# Although again you'll obviously need to personalise this for you.

# %%
auth_file = r"C:\Users\Dom_W\Documents\Development\Projects\sharing\daily_google_analytics_v3\credentials\credentials.json"

# %% [markdown]
# **Action:**
#
# Optional: We could then also set metrics & dimensions to customise what we get back from GA.
#
# I find the [query explorer](https://ga-dev-tools.appspot.com/query-explorer/) really useful for this.
#
# - metrics
# - dimensions

# %%
metrics = "ga:sessions"
dimensions = "ga:landingPagePath"

# %% [markdown]
# **Context:**
#
# Finally we download our data and save it into an object called `df`.

# %%
df = daily_ga_data.download_v3({
    "account_id": account_id,
    "web_property_id": web_property_id,
    "view_id": view_id,
    "start_date": start_date,
    "end_date": end_date,
    "auth_type": "service",
    "auth_file": auth_file,
    "total_results_per_day": False,
    "query_params": {
        "metrics": metrics,
        "dimensions": dimensions,
        "max_results": 10000,
    }
})

# %% [markdown]
# **Context:**
#
# This next cell will copy the output to our clipboard.

# %%
df.to_clipboard()

# %% [markdown]
# **Optional:**
#
# If you don't want the data split by day, we can now group it to get rid of that.

# %%
df_no_time = df.groupby(dimensions).agg({
    'ga:sessions': 'sum',
}).reset_index()

# %%
df_no_time.to_clipbo
# Out:
#                                     ga:landingPagePath  ga:sessions
# 0                                            (not set)           71
# 1                                                    /          193
# 2                 /([/?](?!((foo|bar)=))[^=$]+=)([^&$=            1
# 3                                                /404/            1
# 4    /?_hsenc=p2ANqtz-9MDxHUTToU8VTsO2Lm1QcwJpOyEkd...            1
# 5                                /?email_uid=890845397            1
# 6    /?fbclid=IwAR39TLuR6PYt130hRHP7eKjHkF7LXkfW45j...            1
# 7                                              /about/            4
# 8                                       /about/people/            7
# 9                   /about/people/lynsey-little/posts/            1
# 10               /about/people/maryna-samokhina/posts/            1
# 11                           /about/people/rob-ousbey/            2
# 12                      /about/people/sergey-stefoglo/            1
# 13                           /about/people/siena-sara/            1
# 14                           /about/people/tom-capper/            1
# 15                         /about/people/vicke-cheung/            1
# 16                       /about/people/will-critchlow/            7
# 17                                            /apples/            1
# 18                                            /awards/            1
# 19                  /blog/7-steps-to-a-seamless-shoot/            1
# 20   /blog/conversion-rate-optimization/designing-f...            1
# 21   /blog/distilled/content/how-to-kick-ass-at-cop...            4
# 22   /blog/distilled/content/producing-great-conten...            1
# 23    /blog/distilled/content/the-curse-of-the-cliche/            1
# 24     /blog/distilled/guide-to-google-docs-importxml/           92
# 25   /blog/distilled/how-to-put-together-a-killer-p...            2
# 26   /blog/distilled/outreach/how-to-stay-motivated...            1
# 27   /blog/distilled/the-difference-between-plannin...            1
# 28          /blog/distilled/usability-versus-dyslexia/            1
# 29   /blog/distilled/using-customer-surveys-to-defi...            1
# ..                                                 ...          ...
# 333                                /u/?r=willcritchlow            2
# 334                                /u/?ref=producthunt            1
# 335                                          /u/admin/            1
# 336          /u/analytics-and-measurement/test/answers            1
# 337                                 /u/change_payment/            1
# 338                            /u/competitor-research/            2
# 339                                     /u/consulting/            1
# 340                         /u/enrol_overlay/?virtual=            1
# 341                       /u/information-architecture/            2
# 342                                 /u/interactive-ga/            1
# 343                               /u/interactive-meta/            1
# 344                              /u/international-seo/            2
# 345                               /u/keyword-research/            1
# 346                                       /u/linkbait/            2
# 347                           /u/on-page-optimization/            4
# 348               /u/on-page-optimization/test/answers            1
# 349                          /u/other-ranking-factors/            2
# 350                                     /u/robots-txt/            2
# 351                           /u/search-engine-basics/           11
# 352                       /u/search-engine-basics/test            1
# 353                               /u/search-operators/            1
# 354                                      /u/technical/            4
# 355                                  /u/technical/test            2
# 356                                        /u/toolkit/            1
# 357               /unsubscribing-tips-email-marketing/            3
# 358                                  /user/Bizallegri/            1
# 359                             /user/dorileemarie/?b=            1
# 360                               /user/nicolasegosum/            1
# 361                          /website-migration-guide/            2
# 362                                /word2vec-examples/            9
#
# [363 rows x 2 columns]
